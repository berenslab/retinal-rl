# %%
# %cd ..
# Out:
# /home/alex404/code/retinal-rl

# %%
import numpy as np
import matplotlib as mpl

import matplotlib.pyplot as plt
plt.style.use('misc/default.mplstyle')

# %%
stas = np.load(
    "train_dir/analyze_tester4/analyses/data/stas.npy",
    allow_pickle=True,
).tolist()

# %%
for ky in stas:
    
    lyr = stas[ky]
    ochns,nclrs,_,_ = lyr.shape
    mx = np.amax(lyr)
    mn = np.amin(lyr)
    print(mn,mx)

    fig, axs = plt.subplots(
        nclrs,ochns,
        figsize=(ochns, nclrs),
        facecolor="white",
        dpi=200,
        layout="constrained",
        )
    
    clrs = ['red','green','blue']
    cmaps = ['inferno', 'viridis', 'cividis']

    print(axs)

    for i in range(ochns):
        for j in range(nclrs):
            ax = axs[j][i]
            im = ax.imshow(lyr[i,j,:,:],cmap=cmaps[j],vmin=mn,vmax=mx)
            ax.set_xticks([])
            ax.set_yticks([])
            ax.spines["top"].set_visible(True)
            ax.spines["right"].set_visible(True)
            
            if i==0:
                fig.colorbar(im, ax=ax,cmap=cmaps[j],label=clrs[j],location="left")
# Out:
# -0.47107774019241333 0.3674933612346649
# [[<Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >
#   <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >
#   <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >
#   <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]]
# -1.4106358289718628 1.4930729866027832
# [[<Axes: > <Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: > <Axes: >]]
# -0.372150719165802 0.4487565755844116
# [[<Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >
#   <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >
#   <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >
#   <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]]
